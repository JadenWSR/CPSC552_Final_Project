# %% [markdown]
# # Detecting Human-AI Generated Texts: A Multi-Method Classification Approach with Compact Style Embeddings

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split, Subset
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import Dataset

import pytorch_lightning as pl
from pytorch_lightning import Trainer, loggers
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping

from torchmetrics import Accuracy, F1Score

from transformers import DistilBertModel, DistilBertTokenizer, MobileBertModel, MobileBertTokenizer, PreTrainedTokenizer,MobileBertForSequenceClassification

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

import numpy as np
from datasets import load_dataset

from tokenizers import Tokenizer
import random

from cpus import numcores
import pandas as pd
import os
import json

# %%
workers = numcores()
print(f'This device has {workers} cores.')
# Out:
# This device has 10 cores.

# %%
# set the device
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
elif torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    if not torch.backends.mps.is_built():
        print("MPS not available because the current PyTorch install was not "
              "built with MPS enabled.")
    else:
        print("MPS not available because the current MacOS version is not 12.3+ "
              "and/or you do not have an MPS-enabled device on this machine.")
    DEVICE = torch.device("cpu")
    print("Warning: You are using CPU. For better performance, use GPU.")
print("Pytorch version is: ", torch.__version__)
print("You are using: ", DEVICE)
# Out:
# Pytorch version is:  2.2.2+cu121
# You are using:  cuda

# %% [markdown]
# ## Tokenization and Model Initialization
# We’ll define a function to initialize the tokenizer and model based on the choice.

# %%
def initialize_model(model_name='distilbert'):
    if model_name == 'mobilebert':
        tokenizer = MobileBertTokenizer.from_pretrained('google/mobilebert-uncased')
        model = MobileBertModel.from_pretrained('google/mobilebert-uncased').to(DEVICE)
    else:  # Default to DistilBERT
        tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
        model = DistilBertModel.from_pretrained('distilbert-base-uncased').to(DEVICE)
    return tokenizer, model

#tokenizer, bert_model = initialize_model('distilbert')  # or 'mobilebert'
tokenizer, bert_model = initialize_model('mobilebert')

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ### Mixset

# %% [markdown]
# The training set consists of 3,000 entries and the test set has 600 entries. 83.3\% of this dataset is MGT, and the rest of it is HWT.

# %%
# mixset = load_dataset("shuaishuaicdp/MixSet")

# %%
def read_json_file(file_path):
    # Open and load the JSON file
    with open(file_path, 'r', encoding='utf-8') as file:
        file_data = json.load(file)
    
    # Extract the 'revised' and 'binary' fields and store them in a list
    data = [(item['revised'], item['binary']) for item in file_data]

    # Convert list to DataFrame
    return pd.DataFrame(data, columns=['Revised', 'Binary'])

# %%
# Usage
data_folder = os.path.join(os.getcwd(), 'data')  # Construct the path to the data folder
test_file_path = os.path.join(data_folder, 'Mixset_test.json')  # Path to the test JSON file
train_file_path = os.path.join(data_folder, 'Mixset_train.json')  # Path to the train JSON file

# Read files and create DataFrames
mixset_test = read_json_file(test_file_path)
mixset_train = read_json_file(train_file_path)

# %% [markdown]
# Data Example:
# ```
# {
#         "category": "speech",
#         "id": 3000,
#         "original": "Two twin domes, two radically opposed design cultures. One is made of thousands of steel parts, the other of a single silk thread. One is synthetic, the other organic. One is imposed on the environment, the other creates it. One is designed for nature, the other is designed by her.michelangelo said that when he looked at raw marble, he saw a figure struggling to be free. The chisel was michelangelo's only tool. But living things are not chiseled. They grow. And in our smallest units of life, our cells, we carry all the information that's required for every other cell to function and to replicate.tools also have consequences. At least since the industrial revolution, the world of design has been dominated by the rigors of manufacturing and mass production.",
#         "revised": "Two identical domes, two fundamentally different design philosophies. One consists of thousands of metallic components, while the other is crafted from a singular silken strand. One is artificial, the other natural. One imposes itself upon the environment, while the other is created by it. One is designed for nature, the other is designed by Nature herself. Michelangelo believed that when he gazed upon unhewn marble, he witnessed a form yearning to be liberated. His chisel served as the instrument to release its inherent beauty. However, living entities do not conform to such sculptural constraints; they develop and flourish through growth. Within our minuscule biological building blocks, known as cells, resides all the necessary knowledge for their own operation and propagation, as well as that of every other cell. Tools possess implications beyond their intended use. Since the advent of the Industrial Revolution, the realm of design has been governed by the principles of fabrication and large-scale production.",
#         "mixset_category": "2llama_polish_token",
#         "binary": "MGT"
#     }
# ```

# %% [markdown]
# However, the scale of the MixSet Dataset is relatively small. Thus we downloaded `Augmented data for LLM - Detect AI Generated Text` dataset from kaggle, which consists of pure AI and pure human text. We will draw samples from llm dataset to make mixset a balance dataset, with 3 classes: pure human, pure AI, and Mix.

# %%
# LLM dataset


train_csv = pd.read_csv(os.path.join(data_folder, 'final_train.csv'))
test_csv = pd.read_csv(os.path.join(data_folder, 'final_test.csv'))

# %%
# Count of mixed texts (MGT) and human texts (HWT) in mixset
mix_train_counts = mixset_train['Binary'].value_counts()
mix_test_counts = mixset_test['Binary'].value_counts()

# Assume the number of mixed texts to be fixed and define the sample sizes
num_mixed = mix_train_counts['MGT']
num_human_hwt = mix_train_counts['HWT']

# Sample pure AI and pure human texts from CSV dataset
pure_ai_train = train_csv[train_csv['label'] == 1].sample(n=num_mixed, random_state=42)
pure_human_train = train_csv[train_csv['label'] == 0].sample(n=(num_mixed - num_human_hwt), random_state=42)

pure_ai_test = test_csv[test_csv['label'] == 1].sample(n=mix_test_counts['MGT'], random_state=42)
pure_human_test = test_csv[test_csv['label'] == 0].sample(n=(mix_test_counts['MGT'] - mix_test_counts['HWT']), random_state=42)

# Combine the datasets
combined_train = pd.concat([
    pd.DataFrame({'Text': pure_ai_train['text'], 'Label': 'PureAI'}),
    pd.DataFrame({'Text': pure_human_train['text'], 'Label': 'PureHuman'}),
    pd.DataFrame({'Text': mixset_train[mixset_train['Binary'] == 'MGT']['Revised'], 'Label': 'Mixed'}),
    pd.DataFrame({'Text': mixset_train[mixset_train['Binary'] == 'HWT']['Revised'], 'Label': 'PureHuman'})
])

combined_test = pd.concat([
    pd.DataFrame({'Text': pure_ai_test['text'], 'Label': 'PureAI'}),
    pd.DataFrame({'Text': pure_human_test['text'], 'Label': 'PureHuman'}),
    pd.DataFrame({'Text': mixset_test[mixset_test['Binary'] == 'MGT']['Revised'], 'Label': 'Mixed'}),
    pd.DataFrame({'Text': mixset_test[mixset_test['Binary'] == 'HWT']['Revised'], 'Label': 'PureHuman'})
])

# Shuffle the datasets to mix the entries properly
combined_train = combined_train.sample(frac=1, random_state=42).reset_index(drop=True)
combined_test = combined_test.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# We randomly draw 5\% of the training set as validation set.

# %%
def create_train_validation_split(dataset, val_size=0.05, random_seed=42):
    """
    Splits the DataFrame into training and validation DataFrames in a stratified manner,
    ensuring that each class is represented in the validation set in proportion to its occurrence in the full dataset.

    Args:
        dataset (pandas.DataFrame): The complete dataset from which to create subsets.
        val_size (float, optional): The proportion of the dataset to use for validation.
        random_seed (int, optional): A seed for the random number generator for reproducibility.

    Returns:
        Tuple[pandas.DataFrame, pandas.DataFrame]: Training and validation DataFrames.
    """
    # Check if the dataset has a column named 'Label'
    if 'Label' not in dataset.columns:
        raise ValueError("Dataset must have a 'Label' column for stratified splitting")

    # Calculate the number of samples to include in each set using the specified validation size
    train_df, val_df = train_test_split(
        dataset, 
        test_size=val_size, 
        random_state=random_seed, 
        stratify=dataset['Label']
    )

    return train_df, val_df

# %%
combined_train, combined_val = create_train_validation_split(combined_train)

# %% [markdown]
# ## Creating the Custom Dataset Class
# We will creating a custom dataset class for the triplet model. It requires organizing our data into triplets in a way that each triplet consists of texts that are likely to have similar style characteristics but different content. Since the goal is to identify whether a text is from a human, AI, or a mixture, we need to structure the triplet as follows:
#
# - Anchor (A1): A sample from any class.
# - Positive (A2): Another sample from the same class but different content.
# - Negative (B): A sample from a different class.

# %% [markdown]
# Since we are using pretrained models (e.g., DistilBERT, MobileBERT) and focusing on style, we decided keeping the stopwords to preserve the full stylistic and semantic integrity of the texts.

# %%
class TripletTextDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=512, seed=None):
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.texts = data['Text']
        self.labels = data['Label']
        self.seed = seed
        
        # Use a dictionary to map text labels to integers
        self.label_mapping = {'PureAI': 0, 'PureHuman': 1, 'Mixed': 2}
        
        # Group indices for each class
        self.class_indices = {'PureAI': [], 'PureHuman': [], 'Mixed': []}
        for index, label in enumerate(self.labels):
            self.class_indices[label].append(index)

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        if self.seed is not None:
            random.seed(self.seed)

        anchor_text = self.texts.iloc[idx]
        anchor_label = self.labels.iloc[idx]

        # Map the label string to an integer
        mapped_label = self.label_mapping[anchor_label]

        pos_index = idx
        while pos_index == idx:  # Ensure a different text for positive example
            pos_index = random.choice(self.class_indices[anchor_label])
        positive_text = self.texts.iloc[pos_index]

        neg_label = random.choice([l for l in self.label_mapping if l != anchor_label])
        neg_index = random.choice(self.class_indices[neg_label])
        negative_text = self.texts.iloc[neg_index]

        # Tokenize texts
        anchor_enc = self.tokenizer(anchor_text, add_special_tokens=True, 
                                    max_length=self.max_length, truncation=True,
                                    padding='max_length', return_tensors='pt')
        positive_enc = self.tokenizer(positive_text, add_special_tokens=True, 
                                      max_length=self.max_length, truncation=True,
                                      padding='max_length', return_tensors='pt')
        negative_enc = self.tokenizer(negative_text, add_special_tokens=True, 
                                      max_length=self.max_length, truncation=True,
                                      padding='max_length', return_tensors='pt')

        return {
            'anchor': anchor_enc['input_ids'].squeeze(0),
            'positive': positive_enc['input_ids'].squeeze(0),
            'negative': negative_enc['input_ids'].squeeze(0),
            'anchor_mask': anchor_enc['attention_mask'].squeeze(0),
            'positive_mask': positive_enc['attention_mask'].squeeze(0),
            'negative_mask': negative_enc['attention_mask'].squeeze(0),
            'labels': torch.tensor(mapped_label)  # Now this is a valid tensor conversion
        }

# %% [markdown]
# we will leverage PyTorch's DataLoader to greatly simplify sampling and batching.

# %%
train_dataset = TripletTextDataset(combined_train, tokenizer)
val_dataset = TripletTextDataset(combined_val, tokenizer)
test_dataset = TripletTextDataset(combined_test, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers = workers-1)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, num_workers = workers-1)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers = workers-1)

# %% [markdown]
# ## Model creation

# %%
class TripletModelPL(pl.LightningModule):
    def __init__(self, bert_model, learning_rate=1e-4, wd = 0.01):
        super().__init__()
        self.bert_model = bert_model
        self.learning_rate = learning_rate
        self.weight_decay = wd

    def forward(self, A1_ids, A2_ids, B_ids, A1_mask, A2_mask, B_mask):
        A1_emb = self.bert_model(A1_ids, attention_mask=A1_mask).pooler_output
        A2_emb = self.bert_model(A2_ids, attention_mask=A2_mask).pooler_output
        B_emb = self.bert_model(B_ids, attention_mask=B_mask).pooler_output
        return A1_emb, A2_emb, B_emb

    def training_step(self, batch, batch_idx):
        pos_dist, neg_dist = self._get_triplet_distances(batch)
        loss = self.triplet_loss(pos_dist, neg_dist)
        self.log('train_loss', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        pos_dist, neg_dist = self._get_triplet_distances(batch)
        loss = self.triplet_loss(pos_dist, neg_dist)
        self.log('val_loss', loss)
        return loss

    def test_step(self, batch, batch_idx):
        pos_dist, neg_dist = self._get_triplet_distances(batch)
        loss = self.triplet_loss(pos_dist, neg_dist)
        accuracy = self.calculate_accuracy(pos_dist, neg_dist)
        self.log('test_loss', loss)
        self.log('test_accuracy', accuracy)
        return {'test_loss': loss, 'test_accuracy': accuracy}

    def calculate_accuracy(self, pos_dist, neg_dist):
        correct = (pos_dist < neg_dist).float()
        return correct.mean()

    def _get_triplet_distances(self, batch):
        A1_ids, A2_ids, B_ids = batch['anchor'], batch['positive'], batch['negative']
        A1_mask, A2_mask, B_mask = batch['anchor_mask'], batch['positive_mask'], batch['negative_mask']
        A1_emb, A2_emb, B_emb = self(A1_ids, A2_ids, B_ids, A1_mask, A2_mask, B_mask)
        pos_dist = F.pairwise_distance(A1_emb, A2_emb, 2)
        neg_dist = F.pairwise_distance(A1_emb, B_emb, 2)
        return pos_dist, neg_dist


    def triplet_loss(self, pos_dist, neg_dist, margin=0.5):
        loss = F.relu(pos_dist - neg_dist + margin)
        return loss.mean()

    def configure_optimizers(self):
        return Adam(self.parameters(), lr=self.learning_rate,weight_decay = self.weight_decay)

# %%
# Create the model
Tripletmodel = TripletModelPL(bert_model, learning_rate = 0.00002)

# %%
logger = loggers.TensorBoardLogger("tb_logs", name="triplet_model")

# Checkpoint callback to save the best model
checkpoint_callback = ModelCheckpoint(
    monitor='val_loss',
    dirpath=str(os.path.join(os.getcwd(), 'checkpoints/')),   # Directory where models are saved
    filename='model-{epoch:02d}-{val_loss:.2f}',
    save_top_k=1,
    mode='min'
)

# Early stopping callback
early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=3,
    verbose=True,
    mode='min'
)

# Setup the trainer with added callbacks for checkpointing and early stopping
trainer = Trainer(
    max_epochs=10,
    callbacks=[checkpoint_callback, early_stopping_callback],
    logger=logger,
    accumulate_grad_batches=1,
    gradient_clip_val=100,
    gradient_clip_algorithm='value',
)
# Out:
# /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3.12/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3 ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# Train the model
trainer.fit(Tripletmodel, train_loader, val_loader)
# Out:
# /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3.12/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3 ...
# You are using a CUDA device ('NVIDIA RTX A5000') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3.12/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:653: Checkpoint directory /gpfs/gibbs/project/cpsc452/cpsc452_sw2349/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type            | Params
# -----------------------------------------------
# 0 | bert_model | MobileBertModel | 24.6 M
# -----------------------------------------------
# 24.6 M    Trainable params
# 0         Non-trainable params
# 24.6 M    Total params
# 98.328    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved. New best score: 36289.340
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 27110.768 >= min_delta = 0.0. New best score: 9178.572
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 2476.431 >= min_delta = 0.0. New best score: 6702.141
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 4571.101 >= min_delta = 0.0. New best score: 2131.041
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 362.885 >= min_delta = 0.0. New best score: 1768.155
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 686.027 >= min_delta = 0.0. New best score: 1082.128
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 1032.416 >= min_delta = 0.0. New best score: 49.712
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 25.784 >= min_delta = 0.0. New best score: 23.929
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 12.962 >= min_delta = 0.0. New best score: 10.967
# `Trainer.fit` stopped: `max_epochs=10` reached.

# %%
# Test the model
trainer.test(Tripletmodel, test_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.9639999866485596     │
# │         test_loss         │    34.441890716552734     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 34.441890716552734, 'test_accuracy': 0.9639999866485596}]

# %%
def generate_embeddings(model, dataloader):
    model.eval()
    embeddings = []
    labels = []
    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['anchor']
            attention_mask = batch['anchor_mask']
            outputs = model(input_ids, input_ids, input_ids, attention_mask, attention_mask, attention_mask)
            embeddings.extend(outputs[0].cpu().numpy())  # Assuming outputs[0] are the embeddings
            labels.extend(batch['labels'].cpu().numpy())  # Now correctly accessing labels
    return np.array(embeddings), np.array(labels)


# Generate embeddings for the entire dataset
train_embeddings, train_labels = generate_embeddings(Tripletmodel, train_loader)
val_embeddings, val_labels = generate_embeddings(Tripletmodel, val_loader)
test_embeddings, test_labels = generate_embeddings(Tripletmodel, test_loader)

# %%
# Save embeddings and labels
np.save('train_embeddings.npy', train_embeddings)
np.save('train_labels.npy', train_labels)
np.save('val_embeddings.npy', val_embeddings)
np.save('val_labels.npy', val_labels)
np.save('test_embeddings.npy', test_embeddings)
np.save('test_labels.npy', test_labels)

# %%
# Load embeddings and labels
train_embeddings = np.load('train_embeddings.npy')
train_labels = np.load('train_labels.npy')
val_embeddings = np.load('val_embeddings.npy')
val_labels = np.load('val_labels.npy')
test_embeddings = np.load('test_embeddings.npy')
test_labels = np.load('test_labels.npy')

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(MLP, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        out = self.layer1(x)
        out = self.relu(out)
        out = self.layer2(out)
        return out

# Define the input size, hidden layer size, and number of classes
input_size = train_embeddings.shape[1]
hidden_size = 100  # Example: 100 hidden units
num_classes = 3  # 3 classes

# Initialize the MLP
model = MLP(input_size, hidden_size, num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.001)

# %%
# Convert numpy arrays to torch tensors
train_embeddings_tensor = torch.tensor(train_embeddings).float()
train_labels_tensor = torch.tensor(train_labels).long()
val_embeddings_tensor = torch.tensor(val_embeddings).float()
val_labels_tensor = torch.tensor(val_labels).long()
test_embeddings_tensor = torch.tensor(test_embeddings).float()
test_labels_tensor = torch.tensor(test_labels).long()

best_val_accuracy = 0
model_path = 'best_model.pth'

# Train the model
epochs = 300
for epoch in range(epochs):
    model.train()
    outputs = model(torch.tensor(train_embeddings).float())
    loss = criterion(outputs, torch.tensor(train_labels).long())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Validation
    model.eval()
    with torch.no_grad():
        val_outputs = model(torch.tensor(val_embeddings).float())
        _, predicted = torch.max(val_outputs, 1)
        correct = (predicted == torch.tensor(val_labels).long()).sum().item()
        total = val_labels.shape[0]
        val_accuracy = 100 * correct / total

    # Save the model if it has the best validation accuracy so far
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), model_path)
        print(f"Saved new best model with Validation Accuracy: {val_accuracy}%")

    print(f'Epoch {epoch+1}: Train Loss: {loss.item()}, Validation Accuracy: {val_accuracy}%')
# Out:
# Saved new best model with Validation Accuracy: 33.333333333333336%
# Epoch 1: Train Loss: 688.8220825195312, Validation Accuracy: 33.333333333333336%
# Epoch 2: Train Loss: 1131.275146484375, Validation Accuracy: 33.333333333333336%
# Epoch 3: Train Loss: 1781.82373046875, Validation Accuracy: 33.333333333333336%
# Epoch 4: Train Loss: 1689.6619873046875, Validation Accuracy: 33.333333333333336%
# Epoch 5: Train Loss: 1123.2041015625, Validation Accuracy: 33.333333333333336%
# Epoch 6: Train Loss: 925.990478515625, Validation Accuracy: 33.333333333333336%
# Epoch 7: Train Loss: 840.9747314453125, Validation Accuracy: 33.333333333333336%
# Epoch 8: Train Loss: 493.4176940917969, Validation Accuracy: 33.333333333333336%
# Epoch 9: Train Loss: 403.7736511230469, Validation Accuracy: 33.333333333333336%
# Epoch 10: Train Loss: 546.0785522460938, Validation Accuracy: 33.333333333333336%
# Epoch 11: Train Loss: 472.62811279296875, Validation Accuracy: 33.333333333333336%
# Epoch 12: Train Loss: 241.84176635742188, Validation Accuracy: 33.333333333333336%
# Epoch 13: Train Loss: 510.74200439453125, Validation Accuracy: 33.333333333333336%
# Epoch 14: Train Loss: 613.518310546875, Validation Accuracy: 33.333333333333336%
# Epoch 15: Train Loss: 526.5430297851562, Validation Accuracy: 33.333333333333336%
# Epoch 16: Train Loss: 288.1923828125, Validation Accuracy: 33.333333333333336%
# Epoch 17: Train Loss: 306.336669921875, Validation Accuracy: 33.333333333333336%
# Epoch 18: Train Loss: 429.37725830078125, Validation Accuracy: 33.333333333333336%
# Saved new best model with Validation Accuracy: 34.4%
# Epoch 19: Train Loss: 404.42657470703125, Validation Accuracy: 34.4%
# Epoch 20: Train Loss: 255.34292602539062, Validation Accuracy: 33.333333333333336%
# Epoch 21: Train Loss: 308.46929931640625, Validation Accuracy: 33.333333333333336%
# Epoch 22: Train Loss: 360.822021484375, Validation Accuracy: 33.333333333333336%
# Saved new best model with Validation Accuracy: 43.733333333333334%
# Epoch 23: Train Loss: 287.1590576171875, Validation Accuracy: 43.733333333333334%
# Epoch 24: Train Loss: 112.83197021484375, Validation Accuracy: 33.333333333333336%
# Epoch 25: Train Loss: 292.11920166015625, Validation Accuracy: 33.333333333333336%
# Epoch 26: Train Loss: 313.7348327636719, Validation Accuracy: 33.333333333333336%
# Saved new best model with Validation Accuracy: 44.0%
# Epoch 27: Train Loss: 197.23997497558594, Validation Accuracy: 44.0%
# Epoch 28: Train Loss: 46.77653884887695, Validation Accuracy: 33.6%
# Saved new best model with Validation Accuracy: 51.2%
# Epoch 29: Train Loss: 167.04244995117188, Validation Accuracy: 51.2%
# Saved new best model with Validation Accuracy: 66.66666666666667%
# Epoch 30: Train Loss: 183.798583984375, Validation Accuracy: 66.66666666666667%
# Epoch 31: Train Loss: 211.49575805664062, Validation Accuracy: 50.666666666666664%
# Epoch 32: Train Loss: 222.9557647705078, Validation Accuracy: 46.93333333333333%
# Epoch 33: Train Loss: 180.91111755371094, Validation Accuracy: 63.2%
# Epoch 34: Train Loss: 79.73851013183594, Validation Accuracy: 60.266666666666666%
# Epoch 35: Train Loss: 46.79631423950195, Validation Accuracy: 35.2%
# Epoch 36: Train Loss: 136.5841064453125, Validation Accuracy: 50.13333333333333%
# Epoch 37: Train Loss: 116.14442443847656, Validation Accuracy: 64.53333333333333%
# Epoch 38: Train Loss: 62.14482116699219, Validation Accuracy: 44.266666666666666%
# Epoch 39: Train Loss: 67.8604965209961, Validation Accuracy: 65.33333333333333%
# Epoch 40: Train Loss: 84.3259506225586, Validation Accuracy: 66.66666666666667%
# Epoch 41: Train Loss: 98.0350341796875, Validation Accuracy: 66.13333333333334%
# Saved new best model with Validation Accuracy: 69.06666666666666%
# Epoch 42: Train Loss: 70.36976623535156, Validation Accuracy: 69.06666666666666%
# Epoch 43: Train Loss: 1.9113212823867798, Validation Accuracy: 34.93333333333333%
# Epoch 44: Train Loss: 121.1163101196289, Validation Accuracy: 33.6%
# Epoch 45: Train Loss: 149.85289001464844, Validation Accuracy: 61.333333333333336%
# Epoch 46: Train Loss: 76.83159637451172, Validation Accuracy: 57.06666666666667%
# Epoch 47: Train Loss: 8.993886947631836, Validation Accuracy: 65.86666666666666%
# Epoch 48: Train Loss: 86.65448760986328, Validation Accuracy: 66.13333333333334%
# Epoch 49: Train Loss: 125.14490509033203, Validation Accuracy: 66.13333333333334%
# Epoch 50: Train Loss: 120.5075454711914, Validation Accuracy: 65.06666666666666%
# Epoch 51: Train Loss: 80.38056182861328, Validation Accuracy: 63.733333333333334%
# Epoch 52: Train Loss: 14.753949165344238, Validation Accuracy: 63.46666666666667%
# Epoch 53: Train Loss: 74.35245513916016, Validation Accuracy: 39.46666666666667%
# Epoch 54: Train Loss: 121.97586059570312, Validation Accuracy: 43.733333333333334%
# Epoch 55: Train Loss: 81.77241516113281, Validation Accuracy: 65.6%
# Epoch 56: Train Loss: 8.215782165527344, Validation Accuracy: 65.6%
# Epoch 57: Train Loss: 42.07606506347656, Validation Accuracy: 66.66666666666667%
# Epoch 58: Train Loss: 29.371601104736328, Validation Accuracy: 65.86666666666666%
# Epoch 59: Train Loss: 20.47173309326172, Validation Accuracy: 65.6%
# Saved new best model with Validation Accuracy: 85.86666666666666%
# Epoch 60: Train Loss: 28.685638427734375, Validation Accuracy: 85.86666666666666%
# Epoch 61: Train Loss: 2.256366014480591, Validation Accuracy: 66.13333333333334%
# Epoch 62: Train Loss: 25.952470779418945, Validation Accuracy: 66.13333333333334%
# Epoch 63: Train Loss: 8.795714378356934, Validation Accuracy: 66.13333333333334%
# Epoch 64: Train Loss: 43.256187438964844, Validation Accuracy: 65.06666666666666%
# Epoch 65: Train Loss: 52.98568344116211, Validation Accuracy: 66.13333333333334%
# Epoch 66: Train Loss: 23.092859268188477, Validation Accuracy: 66.66666666666667%
# Epoch 67: Train Loss: 40.556617736816406, Validation Accuracy: 65.6%
# Epoch 68: Train Loss: 59.440338134765625, Validation Accuracy: 66.66666666666667%
# Epoch 69: Train Loss: 32.62126922607422, Validation Accuracy: 64.53333333333333%
# Epoch 70: Train Loss: 28.481685638427734, Validation Accuracy: 61.6%
# Epoch 71: Train Loss: 47.16102600097656, Validation Accuracy: 64.26666666666667%
# Epoch 72: Train Loss: 21.897789001464844, Validation Accuracy: 66.13333333333334%
# Epoch 73: Train Loss: 36.25261306762695, Validation Accuracy: 65.6%
# Epoch 74: Train Loss: 50.90487289428711, Validation Accuracy: 66.66666666666667%
# Epoch 75: Train Loss: 20.019201278686523, Validation Accuracy: 64.0%
# Epoch 76: Train Loss: 42.53337860107422, Validation Accuracy: 61.333333333333336%
# Epoch 77: Train Loss: 63.86232376098633, Validation Accuracy: 64.26666666666667%
# Epoch 78: Train Loss: 40.33367156982422, Validation Accuracy: 66.4%
# Epoch 79: Train Loss: 13.47216796875, Validation Accuracy: 66.4%
# Saved new best model with Validation Accuracy: 88.53333333333333%
# Epoch 80: Train Loss: 27.07102394104004, Validation Accuracy: 88.53333333333333%
# Epoch 81: Train Loss: 1.4007314443588257, Validation Accuracy: 65.86666666666666%
# Epoch 82: Train Loss: 20.46611976623535, Validation Accuracy: 74.4%
# Epoch 83: Train Loss: 4.1113667488098145, Validation Accuracy: 66.4%
# Epoch 84: Train Loss: 33.90529251098633, Validation Accuracy: 66.4%
# Epoch 85: Train Loss: 31.11600685119629, Validation Accuracy: 70.4%
# Epoch 86: Train Loss: 6.051523208618164, Validation Accuracy: 66.93333333333334%
# Epoch 87: Train Loss: 11.415164947509766, Validation Accuracy: 66.66666666666667%
# Epoch 88: Train Loss: 13.918413162231445, Validation Accuracy: 76.8%
# Epoch 89: Train Loss: 3.135023593902588, Validation Accuracy: 64.53333333333333%
# Epoch 90: Train Loss: 25.086183547973633, Validation Accuracy: 64.8%
# Epoch 91: Train Loss: 17.19171714782715, Validation Accuracy: 66.66666666666667%
# Epoch 92: Train Loss: 21.088459014892578, Validation Accuracy: 66.66666666666667%
# Epoch 93: Train Loss: 21.33417320251465, Validation Accuracy: 65.6%
# Epoch 94: Train Loss: 11.193513870239258, Validation Accuracy: 67.46666666666667%
# Epoch 95: Train Loss: 9.840179443359375, Validation Accuracy: 66.66666666666667%
# Epoch 96: Train Loss: 19.133460998535156, Validation Accuracy: 67.73333333333333%
# Epoch 97: Train Loss: 11.435246467590332, Validation Accuracy: 62.93333333333333%
# Epoch 98: Train Loss: 24.443653106689453, Validation Accuracy: 63.733333333333334%
# Epoch 99: Train Loss: 24.84214973449707, Validation Accuracy: 74.93333333333334%
# Epoch 100: Train Loss: 5.066421031951904, Validation Accuracy: 69.06666666666666%
# Epoch 101: Train Loss: 10.523787498474121, Validation Accuracy: 68.53333333333333%
# Epoch 102: Train Loss: 11.230758666992188, Validation Accuracy: 76.26666666666667%
# Epoch 103: Train Loss: 5.31827974319458, Validation Accuracy: 66.4%
# Epoch 104: Train Loss: 17.06367301940918, Validation Accuracy: 74.66666666666667%
# Epoch 105: Train Loss: 5.240579605102539, Validation Accuracy: 65.33333333333333%
# Epoch 106: Train Loss: 23.39674949645996, Validation Accuracy: 65.6%
# Epoch 107: Train Loss: 19.08854103088379, Validation Accuracy: 68.53333333333333%
# Epoch 108: Train Loss: 11.840777397155762, Validation Accuracy: 68.53333333333333%
# Epoch 109: Train Loss: 11.754964828491211, Validation Accuracy: 66.13333333333334%
# Epoch 110: Train Loss: 14.009590148925781, Validation Accuracy: 68.26666666666667%
# Epoch 111: Train Loss: 10.697794914245605, Validation Accuracy: 68.26666666666667%
# Epoch 112: Train Loss: 14.342144966125488, Validation Accuracy: 71.46666666666667%
# Epoch 113: Train Loss: 8.963851928710938, Validation Accuracy: 64.8%
# Epoch 114: Train Loss: 17.394760131835938, Validation Accuracy: 67.2%
# Epoch 115: Train Loss: 13.232725143432617, Validation Accuracy: 69.06666666666666%
# Epoch 116: Train Loss: 13.830953598022461, Validation Accuracy: 70.13333333333334%
# Epoch 117: Train Loss: 11.556844711303711, Validation Accuracy: 67.73333333333333%
# Epoch 118: Train Loss: 13.38748550415039, Validation Accuracy: 68.8%
# Epoch 119: Train Loss: 11.767807006835938, Validation Accuracy: 71.2%
# Epoch 120: Train Loss: 10.28232192993164, Validation Accuracy: 74.13333333333334%
# Epoch 121: Train Loss: 7.918629169464111, Validation Accuracy: 69.33333333333333%
# Epoch 122: Train Loss: 12.252443313598633, Validation Accuracy: 74.4%
# Epoch 123: Train Loss: 9.0327787399292, Validation Accuracy: 71.46666666666667%
# Epoch 124: Train Loss: 10.198205947875977, Validation Accuracy: 76.53333333333333%
# Epoch 125: Train Loss: 6.112265586853027, Validation Accuracy: 71.46666666666667%
# Epoch 126: Train Loss: 11.294839859008789, Validation Accuracy: 75.73333333333333%
# Epoch 127: Train Loss: 7.588052749633789, Validation Accuracy: 72.53333333333333%
# Epoch 128: Train Loss: 9.553177833557129, Validation Accuracy: 79.2%
# Epoch 129: Train Loss: 5.089072227478027, Validation Accuracy: 72.8%
# Epoch 130: Train Loss: 10.178232192993164, Validation Accuracy: 78.13333333333334%
# Epoch 131: Train Loss: 6.362268447875977, Validation Accuracy: 74.66666666666667%
# Epoch 132: Train Loss: 8.35724925994873, Validation Accuracy: 82.93333333333334%
# Epoch 133: Train Loss: 4.1929802894592285, Validation Accuracy: 74.4%
# Epoch 134: Train Loss: 8.34290885925293, Validation Accuracy: 81.06666666666666%
# Epoch 135: Train Loss: 4.974028587341309, Validation Accuracy: 76.26666666666667%
# Epoch 136: Train Loss: 6.789605617523193, Validation Accuracy: 84.8%
# Epoch 137: Train Loss: 3.280836820602417, Validation Accuracy: 78.13333333333334%
# Epoch 138: Train Loss: 6.4180755615234375, Validation Accuracy: 86.13333333333334%
# Epoch 139: Train Loss: 3.9959216117858887, Validation Accuracy: 78.93333333333334%
# Epoch 140: Train Loss: 5.600607395172119, Validation Accuracy: 86.4%
# Epoch 141: Train Loss: 2.7149808406829834, Validation Accuracy: 81.86666666666666%
# Epoch 142: Train Loss: 4.901406764984131, Validation Accuracy: 87.46666666666667%
# Epoch 143: Train Loss: 3.22633957862854, Validation Accuracy: 82.13333333333334%
# Epoch 144: Train Loss: 4.573439121246338, Validation Accuracy: 88.0%
# Epoch 145: Train Loss: 2.4832329750061035, Validation Accuracy: 86.4%
# Saved new best model with Validation Accuracy: 89.06666666666666%
# Epoch 146: Train Loss: 3.8798251152038574, Validation Accuracy: 89.06666666666666%
# Epoch 147: Train Loss: 2.6600446701049805, Validation Accuracy: 83.2%
# Saved new best model with Validation Accuracy: 90.13333333333334%
# Epoch 148: Train Loss: 3.9772708415985107, Validation Accuracy: 90.13333333333334%
# Epoch 149: Train Loss: 2.431084632873535, Validation Accuracy: 87.2%
# Epoch 150: Train Loss: 3.3939242362976074, Validation Accuracy: 90.13333333333334%
# Epoch 151: Train Loss: 2.430429220199585, Validation Accuracy: 84.53333333333333%
# Epoch 152: Train Loss: 3.453465461730957, Validation Accuracy: 89.06666666666666%
# Epoch 153: Train Loss: 2.576812267303467, Validation Accuracy: 87.2%
# Epoch 154: Train Loss: 3.0715601444244385, Validation Accuracy: 87.73333333333333%
# Epoch 155: Train Loss: 2.506206750869751, Validation Accuracy: 86.4%
# Epoch 156: Train Loss: 2.9102208614349365, Validation Accuracy: 88.26666666666667%
# Epoch 157: Train Loss: 2.7846970558166504, Validation Accuracy: 88.53333333333333%
# Epoch 158: Train Loss: 2.732548475265503, Validation Accuracy: 86.66666666666667%
# Epoch 159: Train Loss: 2.7918801307678223, Validation Accuracy: 88.0%
# Epoch 160: Train Loss: 2.4334282875061035, Validation Accuracy: 88.26666666666667%
# Epoch 161: Train Loss: 2.7432637214660645, Validation Accuracy: 89.6%
# Epoch 162: Train Loss: 2.3970022201538086, Validation Accuracy: 86.66666666666667%
# Epoch 163: Train Loss: 2.763014793395996, Validation Accuracy: 89.6%
# Epoch 164: Train Loss: 2.416430950164795, Validation Accuracy: 89.06666666666666%
# Epoch 165: Train Loss: 2.579617500305176, Validation Accuracy: 87.73333333333333%
# Epoch 166: Train Loss: 2.4366843700408936, Validation Accuracy: 87.46666666666667%
# Epoch 167: Train Loss: 2.4459469318389893, Validation Accuracy: 89.33333333333333%
# Epoch 168: Train Loss: 2.490783214569092, Validation Accuracy: 89.86666666666666%
# Epoch 169: Train Loss: 2.3663454055786133, Validation Accuracy: 87.2%
# Epoch 170: Train Loss: 2.518350601196289, Validation Accuracy: 90.13333333333334%
# Epoch 171: Train Loss: 2.316406726837158, Validation Accuracy: 89.86666666666666%
# Epoch 172: Train Loss: 2.4324076175689697, Validation Accuracy: 89.06666666666666%
# Epoch 173: Train Loss: 2.3245837688446045, Validation Accuracy: 88.0%
# Epoch 174: Train Loss: 2.347263813018799, Validation Accuracy: 89.33333333333333%
# Epoch 175: Train Loss: 2.357013702392578, Validation Accuracy: 89.86666666666666%
# Epoch 176: Train Loss: 2.280622720718384, Validation Accuracy: 87.46666666666667%
# Epoch 177: Train Loss: 2.361855983734131, Validation Accuracy: 90.13333333333334%
# Epoch 178: Train Loss: 2.257584810256958, Validation Accuracy: 89.33333333333333%
# Epoch 179: Train Loss: 2.2977049350738525, Validation Accuracy: 88.0%
# Epoch 180: Train Loss: 2.271141529083252, Validation Accuracy: 89.6%
# Epoch 181: Train Loss: 2.2314705848693848, Validation Accuracy: 89.33333333333333%
# Epoch 182: Train Loss: 2.269150495529175, Validation Accuracy: 89.86666666666666%
# Epoch 183: Train Loss: 2.205305814743042, Validation Accuracy: 88.53333333333333%
# Epoch 184: Train Loss: 2.2287161350250244, Validation Accuracy: 89.33333333333333%
# Epoch 185: Train Loss: 2.2121362686157227, Validation Accuracy: 90.13333333333334%
# Epoch 186: Train Loss: 2.1775832176208496, Validation Accuracy: 88.0%
# Epoch 187: Train Loss: 2.2017433643341064, Validation Accuracy: 90.13333333333334%
# Epoch 188: Train Loss: 2.162792921066284, Validation Accuracy: 90.13333333333334%
# Epoch 189: Train Loss: 2.15594220161438, Validation Accuracy: 89.06666666666666%
# Saved new best model with Validation Accuracy: 90.4%
# Epoch 190: Train Loss: 2.161724328994751, Validation Accuracy: 90.4%
# Epoch 191: Train Loss: 2.125725030899048, Validation Accuracy: 89.86666666666666%
# Epoch 192: Train Loss: 2.1294703483581543, Validation Accuracy: 89.86666666666666%
# Epoch 193: Train Loss: 2.121756076812744, Validation Accuracy: 90.13333333333334%
# Epoch 194: Train Loss: 2.0941450595855713, Validation Accuracy: 89.86666666666666%
# Epoch 195: Train Loss: 2.098294734954834, Validation Accuracy: 89.86666666666666%
# Epoch 196: Train Loss: 2.0850563049316406, Validation Accuracy: 89.86666666666666%
# Epoch 197: Train Loss: 2.0634331703186035, Validation Accuracy: 89.86666666666666%
# Epoch 198: Train Loss: 2.0647592544555664, Validation Accuracy: 89.6%
# Epoch 199: Train Loss: 2.051128387451172, Validation Accuracy: 90.13333333333334%
# Epoch 200: Train Loss: 2.0321168899536133, Validation Accuracy: 90.13333333333334%
# Epoch 201: Train Loss: 2.0302882194519043, Validation Accuracy: 89.6%
# Epoch 202: Train Loss: 2.018733263015747, Validation Accuracy: 90.13333333333334%
# Epoch 203: Train Loss: 2.0004894733428955, Validation Accuracy: 90.13333333333334%
# Epoch 204: Train Loss: 1.9952538013458252, Validation Accuracy: 89.6%
# Epoch 205: Train Loss: 1.986642837524414, Validation Accuracy: 90.13333333333334%
# Epoch 206: Train Loss: 1.9693855047225952, Validation Accuracy: 90.13333333333334%
# Epoch 207: Train Loss: 1.9599589109420776, Validation Accuracy: 89.6%
# Epoch 208: Train Loss: 1.953414797782898, Validation Accuracy: 90.13333333333334%
# Epoch 209: Train Loss: 1.9390968084335327, Validation Accuracy: 90.13333333333334%
# Epoch 210: Train Loss: 1.9256880283355713, Validation Accuracy: 90.13333333333334%
# Epoch 211: Train Loss: 1.9181305170059204, Validation Accuracy: 90.13333333333334%
# Epoch 212: Train Loss: 1.9081308841705322, Validation Accuracy: 89.86666666666666%
# Epoch 213: Train Loss: 1.8940516710281372, Validation Accuracy: 89.86666666666666%
# Epoch 214: Train Loss: 1.8825087547302246, Validation Accuracy: 90.13333333333334%
# Epoch 215: Train Loss: 1.8739835023880005, Validation Accuracy: 90.13333333333334%
# Epoch 216: Train Loss: 1.8633517026901245, Validation Accuracy: 90.4%
# Epoch 217: Train Loss: 1.850182294845581, Validation Accuracy: 90.13333333333334%
# Epoch 218: Train Loss: 1.8383930921554565, Validation Accuracy: 89.86666666666666%
# Epoch 219: Train Loss: 1.8287938833236694, Validation Accuracy: 90.13333333333334%
# Epoch 220: Train Loss: 1.818677544593811, Validation Accuracy: 90.13333333333334%
# Epoch 221: Train Loss: 1.8066903352737427, Validation Accuracy: 89.86666666666666%
# Epoch 222: Train Loss: 1.794272780418396, Validation Accuracy: 90.13333333333334%
# Epoch 223: Train Loss: 1.7830485105514526, Validation Accuracy: 89.6%
# Epoch 224: Train Loss: 1.772820234298706, Validation Accuracy: 90.4%
# Epoch 225: Train Loss: 1.7623517513275146, Validation Accuracy: 90.13333333333334%
# Epoch 226: Train Loss: 1.750970482826233, Validation Accuracy: 90.4%
# Epoch 227: Train Loss: 1.7389849424362183, Validation Accuracy: 89.86666666666666%
# Epoch 228: Train Loss: 1.727065086364746, Validation Accuracy: 90.13333333333334%
# Epoch 229: Train Loss: 1.7156081199645996, Validation Accuracy: 89.86666666666666%
# Epoch 230: Train Loss: 1.7045950889587402, Validation Accuracy: 89.86666666666666%
# Epoch 231: Train Loss: 1.693798303604126, Validation Accuracy: 90.4%
# Epoch 232: Train Loss: 1.683021068572998, Validation Accuracy: 90.13333333333334%
# Epoch 233: Train Loss: 1.6722004413604736, Validation Accuracy: 90.13333333333334%
# Epoch 234: Train Loss: 1.6614155769348145, Validation Accuracy: 90.13333333333334%
# Epoch 235: Train Loss: 1.6508257389068604, Validation Accuracy: 90.13333333333334%
# Epoch 236: Train Loss: 1.6408648490905762, Validation Accuracy: 89.86666666666666%
# Epoch 237: Train Loss: 1.6321284770965576, Validation Accuracy: 89.86666666666666%
# Epoch 238: Train Loss: 1.6266252994537354, Validation Accuracy: 88.53333333333333%
# Epoch 239: Train Loss: 1.6270488500595093, Validation Accuracy: 89.6%
# Epoch 240: Train Loss: 1.6463797092437744, Validation Accuracy: 87.2%
# Epoch 241: Train Loss: 1.6855056285858154, Validation Accuracy: 88.26666666666667%
# Epoch 242: Train Loss: 1.861216425895691, Validation Accuracy: 85.6%
# Epoch 243: Train Loss: 2.080972909927368, Validation Accuracy: 81.6%
# Epoch 244: Train Loss: 3.3586864471435547, Validation Accuracy: 77.86666666666666%
# Epoch 245: Train Loss: 3.9472367763519287, Validation Accuracy: 72.26666666666667%
# Epoch 246: Train Loss: 7.524766445159912, Validation Accuracy: 72.26666666666667%
# Epoch 247: Train Loss: 6.982822895050049, Validation Accuracy: 72.53333333333333%
# Epoch 248: Train Loss: 7.26203727722168, Validation Accuracy: 77.06666666666666%
# Epoch 249: Train Loss: 4.199664115905762, Validation Accuracy: 78.4%
# Epoch 250: Train Loss: 4.396762847900391, Validation Accuracy: 78.4%
# Epoch 251: Train Loss: 3.788682222366333, Validation Accuracy: 74.66666666666667%
# Epoch 252: Train Loss: 5.9824395179748535, Validation Accuracy: 73.6%
# Epoch 253: Train Loss: 6.339754581451416, Validation Accuracy: 70.4%
# Epoch 254: Train Loss: 8.584846496582031, Validation Accuracy: 75.73333333333333%
# Epoch 255: Train Loss: 4.879208564758301, Validation Accuracy: 78.93333333333334%
# Epoch 256: Train Loss: 4.318628787994385, Validation Accuracy: 82.93333333333334%
# Epoch 257: Train Loss: 2.8459999561309814, Validation Accuracy: 81.86666666666666%
# Epoch 258: Train Loss: 3.164632558822632, Validation Accuracy: 83.73333333333333%
# Epoch 259: Train Loss: 2.6004626750946045, Validation Accuracy: 81.86666666666666%
# Epoch 260: Train Loss: 3.304415464401245, Validation Accuracy: 82.93333333333334%
# Epoch 261: Train Loss: 2.9296512603759766, Validation Accuracy: 79.46666666666667%
# Epoch 262: Train Loss: 4.101911544799805, Validation Accuracy: 78.93333333333334%
# Epoch 263: Train Loss: 3.796689033508301, Validation Accuracy: 75.2%
# Epoch 264: Train Loss: 5.510412693023682, Validation Accuracy: 76.26666666666667%
# Epoch 265: Train Loss: 4.873827934265137, Validation Accuracy: 75.2%
# Epoch 266: Train Loss: 5.932444095611572, Validation Accuracy: 77.86666666666666%
# Epoch 267: Train Loss: 4.124082088470459, Validation Accuracy: 78.66666666666667%
# Epoch 268: Train Loss: 4.216395854949951, Validation Accuracy: 83.73333333333333%
# Epoch 269: Train Loss: 2.6868958473205566, Validation Accuracy: 86.66666666666667%
# Epoch 270: Train Loss: 2.4855666160583496, Validation Accuracy: 86.66666666666667%
# Epoch 271: Train Loss: 1.909083604812622, Validation Accuracy: 89.33333333333333%
# Epoch 272: Train Loss: 1.7996617555618286, Validation Accuracy: 87.73333333333333%
# Epoch 273: Train Loss: 1.7165168523788452, Validation Accuracy: 89.6%
# Epoch 274: Train Loss: 1.6929857730865479, Validation Accuracy: 88.26666666666667%
# Epoch 275: Train Loss: 1.6811176538467407, Validation Accuracy: 89.86666666666666%
# Epoch 276: Train Loss: 1.68532395362854, Validation Accuracy: 88.0%
# Epoch 277: Train Loss: 1.6985701322555542, Validation Accuracy: 89.33333333333333%
# Epoch 278: Train Loss: 1.751038908958435, Validation Accuracy: 86.66666666666667%
# Epoch 279: Train Loss: 1.8216663599014282, Validation Accuracy: 87.46666666666667%
# Epoch 280: Train Loss: 2.163618803024292, Validation Accuracy: 84.0%
# Epoch 281: Train Loss: 2.3546555042266846, Validation Accuracy: 81.6%
# Epoch 282: Train Loss: 3.680934429168701, Validation Accuracy: 78.93333333333334%
# Epoch 283: Train Loss: 3.8712544441223145, Validation Accuracy: 74.4%
# Epoch 284: Train Loss: 6.560501575469971, Validation Accuracy: 74.4%
# Epoch 285: Train Loss: 6.258693695068359, Validation Accuracy: 72.53333333333333%
# Epoch 286: Train Loss: 7.709477424621582, Validation Accuracy: 76.8%
# Epoch 287: Train Loss: 4.562836647033691, Validation Accuracy: 79.2%
# Epoch 288: Train Loss: 4.259211540222168, Validation Accuracy: 82.93333333333334%
# Epoch 289: Train Loss: 2.854936122894287, Validation Accuracy: 83.2%
# Epoch 290: Train Loss: 3.117086172103882, Validation Accuracy: 83.73333333333333%
# Epoch 291: Train Loss: 2.5781090259552, Validation Accuracy: 82.4%
# Epoch 292: Train Loss: 3.2422096729278564, Validation Accuracy: 82.93333333333334%
# Epoch 293: Train Loss: 2.9650232791900635, Validation Accuracy: 79.2%
# Epoch 294: Train Loss: 4.308011531829834, Validation Accuracy: 77.86666666666666%
# Epoch 295: Train Loss: 4.2377028465271, Validation Accuracy: 74.66666666666667%
# Epoch 296: Train Loss: 6.427513122558594, Validation Accuracy: 74.93333333333334%
# Epoch 297: Train Loss: 5.587082386016846, Validation Accuracy: 74.4%
# Epoch 298: Train Loss: 6.575108528137207, Validation Accuracy: 77.86666666666666%
# Epoch 299: Train Loss: 4.3296637535095215, Validation Accuracy: 78.66666666666667%
# Epoch 300: Train Loss: 4.341733455657959, Validation Accuracy: 83.73333333333333%

# %%
# Load the best model
best_model = MLP(input_size=train_embeddings.shape[1], hidden_size=100, num_classes=3)
best_model.load_state_dict(torch.load(model_path))

# Use the best model for evaluation or further training
best_model.eval()
# Example: evaluate on test data
with torch.no_grad():
    test_outputs = best_model(torch.tensor(test_embeddings).float())
    _, predicted = torch.max(test_outputs, 1)
    correct = (predicted == torch.tensor(test_labels).long()).sum().item()
    total = test_labels.shape[0]
    test_accuracy = 100 * correct / total
    print(f'Test Accuracy: {test_accuracy}%')
# Out:
# Test Accuracy: 79.0%

# %% [markdown]
# ## Method 2: KNN Classifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# Train the classifier on the training data
knn.fit(train_embeddings, train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Predicting labels for validation set
val_predictions = knn.predict(val_embeddings)

print("Validation Accuracy: ", accuracy_score(val_labels, val_predictions))
print(classification_report(val_labels, val_predictions))
# Out:
# Validation Accuracy:  0.976
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       125
#            1       0.96      0.97      0.96       125
#            2       0.98      1.00      0.99       125
#
#     accuracy                           0.98       375
#    macro avg       0.98      0.98      0.98       375
# weighted avg       0.98      0.98      0.98       375

# %%
# Predicting test set
test_predictions = knn.predict(test_embeddings)
print("Test Accuracy: ", accuracy_score(test_labels, test_predictions))
print(classification_report(test_labels, test_predictions))
# Out:
# Test Accuracy:  0.934
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91       500
#            1       0.98      0.98      0.98       500
#            2       0.99      0.84      0.91       500
#
#     accuracy                           0.93      1500
#    macro avg       0.94      0.93      0.93      1500
# weighted avg       0.94      0.93      0.93      1500

# %% [markdown]
# ## Method 3: SVM classifier

# %%
# Combine training and validation sets for training the final model
X_train = np.vstack((train_embeddings, val_embeddings))
y_train = np.hstack((train_labels, val_labels))

# Test set
X_test = test_embeddings
y_test = test_labels

# %%
#Feature Scaling
#SVMs are sensitive to unscaled features, so it is crucial to normalize or standardize your features:
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Setting up the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': ['scale', 'auto'],  # Kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’
    'kernel': ['linear', 'rbf', 'poly']  # Type of the kernel
}

# Creating the classifier
svm_model = GridSearchCV(SVC(probability=True), param_grid, verbose=2, n_jobs=-1, cv=5)
svm_model.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              verbose=2)

# %%
print("Best parameters found:", svm_model.best_params_)
best_svm = svm_model.best_estimator_
# Out:
# Best parameters found: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}

# %%
y_pred = best_svm.predict(X_test_scaled)

# Evaluation metrics
print("Classification report:")
print(classification_report(y_test, y_pred, digits = 4))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8619    0.9860    0.9198       500
#            1     0.9920    0.9880    0.9900       500
#            2     0.9907    0.8520    0.9161       500
#
#     accuracy                         0.9420      1500
#    macro avg     0.9482    0.9420    0.9420      1500
# weighted avg     0.9482    0.9420    0.9420      1500
#
# Confusion Matrix:
# [[493   4   3]
#  [  5 494   1]
#  [ 74   0 426]]
# Accuracy: 0.942

# %% [markdown]
# ## Method 4: Desision Tree

# %%
# Initialize the Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Fit the model on the training data
dt_classifier.fit(train_embeddings, train_labels)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Predict on the validation set
val_predictions = dt_classifier.predict(val_embeddings)

# Generate classification report
print("Validation Classification Report:")
print(classification_report(val_labels, val_predictions))

# Confusion matrix
print("Validation Confusion Matrix:")
print(confusion_matrix(val_labels, val_predictions))
# Out:
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       125
#            1       0.97      0.97      0.97       125
#            2       0.98      1.00      0.99       125
#
#     accuracy                           0.98       375
#    macro avg       0.98      0.98      0.98       375
# weighted avg       0.98      0.98      0.98       375
#
# Validation Confusion Matrix:
# [[120   4   1]
#  [  2 121   2]
#  [  0   0 125]]

# %%
parameters = {
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

grid_search = GridSearchCV(DecisionTreeClassifier(random_state=42), parameters, verbose=2, n_jobs=-1, cv=5)
grid_search.fit(train_embeddings, train_labels)

print("Best parameters found: ", grid_search.best_params_)
dt_best = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best parameters found:  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
# Predict on the test set
test_predictions = dt_best.predict(test_embeddings)

# Generate classification report
print("Test Classification Report:")
print(classification_report(test_labels, test_predictions, digits = 4))

# Confusion matrix
print("Test Confusion Matrix:")
print(confusion_matrix(test_labels, test_predictions))
# Out:
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8899    0.9700    0.9282       500
#            1     0.9723    0.9820    0.9771       500
#            2     0.9800    0.8820    0.9284       500
#
#     accuracy                         0.9447      1500
#    macro avg     0.9474    0.9447    0.9446      1500
# weighted avg     0.9474    0.9447    0.9446      1500
#
# Test Confusion Matrix:
# [[485   9   6]
#  [  6 491   3]
#  [ 54   5 441]]

# %% [markdown]
# ## Method 5: Logistics Regression

# %%
scaler = StandardScaler()
train_embeddings_scaled = scaler.fit_transform(train_embeddings)
val_embeddings_scaled = scaler.transform(val_embeddings)
test_embeddings_scaled = scaler.transform(test_embeddings)

# %%
# Define the model
model = LogisticRegression(max_iter=1000)

# Train the model
model.fit(train_embeddings_scaled, train_labels)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predictions
val_predictions = model.predict(val_embeddings_scaled)
test_predictions = model.predict(test_embeddings_scaled)

# Evaluation metrics
print("Validation Accuracy:", accuracy_score(val_labels, val_predictions))
print("Test Accuracy:", accuracy_score(test_labels, test_predictions))
print("\nValidation Classification Report:\n", classification_report(val_labels, val_predictions, digits = 4))
print("\nTest Classification Report:\n", classification_report(test_labels, test_predictions, digits = 4))
# Out:
# Validation Accuracy: 0.9813333333333333
# Test Accuracy: 0.9453333333333334
#
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9918    0.9680    0.9798       125
#            1     0.9683    0.9760    0.9721       125
#            2     0.9843    1.0000    0.9921       125
#
#     accuracy                         0.9813       375
#    macro avg     0.9814    0.9813    0.9813       375
# weighted avg     0.9814    0.9813    0.9813       375
#
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8766    0.9800    0.9254       500
#            1     0.9859    0.9820    0.9840       500
#            2     0.9865    0.8740    0.9268       500
#
#     accuracy                         0.9453      1500
#    macro avg     0.9497    0.9453    0.9454      1500
# weighted avg     0.9497    0.9453    0.9454      1500

# %% [markdown]
# ## Baseline Mobile Bert

# %%
model_name = 'google/mobilebert-uncased'
model = MobileBertForSequenceClassification.from_pretrained(model_name, num_labels=3)
tokenizer = MobileBertTokenizer.from_pretrained(model_name)
# Out:
# Some weights of MobileBertForSequenceClassification were not initialized from the model checkpoint at google/mobilebert-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def encode_texts(tokenizer, texts):
    return tokenizer(texts, padding='max_length', truncation=True, max_length=512, return_tensors="pt")

# Assuming combined_test is your DataFrame and Text is the column with texts
encoded_test = encode_texts(tokenizer, combined_test['Text'].tolist())

# %%
with torch.no_grad():  # This will disable gradient calculations
    outputs = model(**encoded_test)
    predictions = torch.argmax(outputs.logits, dim=-1)

# %%
combined_test
# Out:
#                                                    Text      Label
# 0     I have two questions for you. One: whose shoul...      Mixed
# 1     On October 4, 1957, the world watched in awe a...      Mixed
# 2     Failure to Failure Equals Success: The Importa...     PureAI
# 3     Education is a life-long process, and I strong...     PureAI
# 4     I strongly believe that arts education should ...     PureAI
# ...                                                 ...        ...
# 1495  Hello. This is my first trip, first time in li...      Mixed
# 1496  We require a weather service for water, but it...      Mixed
# 1497  I think the state senator should change the el...  PureHuman
# 1498  OMG, so u wanna know how long it'll take to dr...  PureHuman
# 1499  We're seen as the organization that is the buc...      Mixed
#
# [1500 rows x 2 columns]

# %%
label_mapping = {'PureAI': 0, 'PureHuman': 1, 'Mixed': 2}
gt_labels = combined_test['Label'].map(label_mapping)

print(classification_report(gt_labels, predictions.numpy(), target_names=['PureAi', 'PureHuman', 'Mixed'], digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#       PureAi     0.3333    1.0000    0.5000       500
#    PureHuman     0.0000    0.0000    0.0000       500
#        Mixed     0.0000    0.0000    0.0000       500
#
#     accuracy                         0.3333      1500
#    macro avg     0.1111    0.3333    0.1667      1500
# weighted avg     0.1111    0.3333    0.1667      1500
# /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/cpsc452_sw2349/.conda/envs/cpsc552/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
